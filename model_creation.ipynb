# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('data.xlsx')

# %%
data.head()
# Out:
#    CarName  Year  SellingPrice  PresentPrice  KmsDriven FuelType SellerType  \
# 0     ritz  2014          3.35          5.59      27000   Petrol     Dealer
# 1      sx4  2013          4.75          9.54      43000   Diesel     Dealer
# 2     ciaz  2017          7.25          9.85       6900   Petrol     Dealer
# 3  wagon r  2011          2.85          4.15       5200   Petrol     Dealer
# 4    swift  2014          4.60          6.87      42450   Diesel     Dealer
#
#   Tranmission  owner
# 0      Manual      0
# 1      Manual      0
# 2      Manual      0
# 3      Manual      0
# 4      Manual      0

# %%
data.isnull().sum()
# Out:
# CarName         0
# Year            0
# SellingPrice    0
# PresentPrice    0
# KmsDriven       0
# FuelType        0
# SellerType      0
# Tranmission     0
# owner           0
# dtype: int64

# %%
data.describe()
# Out:
#               Year  SellingPrice  PresentPrice      KmsDriven       owner
# count   301.000000    301.000000    301.000000     301.000000  301.000000
# mean   2013.627907      4.661296      7.628472   36947.205980    0.043189
# std       2.891554      5.082812      8.644115   38886.883882    0.247915
# min    2003.000000      0.100000      0.320000     500.000000    0.000000
# 25%    2012.000000      0.900000      1.200000   15000.000000    0.000000
# 50%    2014.000000      3.600000      6.400000   32000.000000    0.000000
# 75%    2016.000000      6.000000      9.900000   48767.000000    0.000000
# max    2018.000000     35.000000     92.600000  500000.000000    3.000000

# %%
data['CurrentYear'] =2021

# %%
data['UsageYear'] = data['CurrentYear'] - data['Year']

# %%
data.drop(['Year'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['CarName', 'SellingPrice', 'PresentPrice', 'KmsDriven', 'FuelType',
#        'SellerType', 'Tranmission', 'owner', 'CurrentYear', 'UsageYear'],
#       dtype='object')

# %%
data.head()
# Out:
#    CarName  SellingPrice  PresentPrice  KmsDriven FuelType SellerType  \
# 0     ritz          3.35          5.59      27000   Petrol     Dealer
# 1      sx4          4.75          9.54      43000   Diesel     Dealer
# 2     ciaz          7.25          9.85       6900   Petrol     Dealer
# 3  wagon r          2.85          4.15       5200   Petrol     Dealer
# 4    swift          4.60          6.87      42450   Diesel     Dealer
#
#   Tranmission  owner  CurrentYear  UsageYear
# 0      Manual      0         2021          7
# 1      Manual      0         2021          8
# 2      Manual      0         2021          4
# 3      Manual      0         2021         10
# 4      Manual      0         2021          7

# %%
data['FuelType'] = data['FuelType'].replace({'Petrol':0,'Diesel':1,'CNG':2})

# %%
data['SellerType'] = data['SellerType'].replace({'Dealer':0,'Individual':1})

# %%
data['Tranmission'] = data['Tranmission'].replace({'Manual':0,'Automatic':1})

# %%
data.head()
# Out:
#    CarName  SellingPrice  PresentPrice  KmsDriven  FuelType  SellerType  \
# 0     ritz          3.35          5.59      27000         0           0
# 1      sx4          4.75          9.54      43000         1           0
# 2     ciaz          7.25          9.85       6900         0           0
# 3  wagon r          2.85          4.15       5200         0           0
# 4    swift          4.60          6.87      42450         1           0
#
#    Tranmission  owner  CurrentYear  UsageYear
# 0            0      0         2021          7
# 1            0      0         2021          8
# 2            0      0         2021          4
# 3            0      0         2021         10
# 4            0      0         2021          7

# %%
data.isnull().sum()
# Out:
# CarName         0
# SellingPrice    0
# PresentPrice    0
# KmsDriven       0
# FuelType        0
# SellerType      0
# Tranmission     0
# owner           0
# CurrentYear     0
# UsageYear       0
# dtype: int64

# %%
data.corr()
# Out:
#               SellingPrice  PresentPrice  KmsDriven  FuelType  SellerType  \
# SellingPrice      1.000000      0.878983   0.029187  0.509467   -0.550724
# PresentPrice      0.878983      1.000000   0.203647  0.440415   -0.512030
# KmsDriven         0.029187      0.203647   1.000000  0.166801   -0.101419
# FuelType          0.509467      0.440415   0.166801  1.000000   -0.352415
# SellerType       -0.550724     -0.512030  -0.101419 -0.352415    1.000000
# Tranmission       0.367128      0.348715   0.162510  0.080466   -0.063240
# owner            -0.088344      0.008057   0.089216 -0.055705    0.124269
# CurrentYear            NaN           NaN        NaN       NaN         NaN
# UsageYear        -0.236141      0.047584   0.524342 -0.053643    0.039896
#
#               Tranmission     owner  CurrentYear  UsageYear
# SellingPrice     0.367128 -0.088344          NaN  -0.236141
# PresentPrice     0.348715  0.008057          NaN   0.047584
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
sns.pairplot(data)

# %%
corrmat = data.corr()
indices = corrmat.index
plt.figure(figsize=(20,20))
sns.heatmap(data[indices].corr(),annot=True,cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['CarName', 'SellingPrice', 'PresentPrice', 'KmsDriven', 'FuelType',
#        'SellerType', 'Tranmission', 'owner', 'CurrentYear', 'UsageYear'],
#       dtype='object')

# %%
data.drop(['CarName','CurrentYear'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['SellingPrice', 'PresentPrice', 'KmsDriven', 'FuelType', 'SellerType',
#        'Tranmission', 'owner', 'UsageYear'],
#       dtype='object')

# %%
X = data.iloc[:,1:]
y = data['SellingPrice']

# %%
from sklearn.ensemble import ExtraTreesRegressor,RandomForestRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
model.feature_importances_
# Out:
# array([3.91578672e-01, 3.72385048e-02, 1.57651027e-01, 2.46390193e-01,
#        8.88431352e-02, 1.79406486e-04, 7.81190623e-02])

# %%
feat = pd.Series(model.feature_importances_,index=X.columns)
feat.nlargest(5).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
regressor = RandomForestRegressor()
n_estimator = [x for x in np.linspace(100,1200,12)]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(100,1200,12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator=regressor,param_distributions=random_grid,scoring="neg_mean_squared_error",cv=5,n_iter=10,verbose=2,n_jobs=1,random_state=42)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.8s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
rf_random.best_score_
# Out:
# -4.166217087564625

# %%
predictions = rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)
# Out:
# <AxesSubplot:xlabel='SellingPrice', ylabel='Density'>

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.8701606593406546
# MSE: 3.875251978973625
# RMSE: 1.9685659701858165

# %%
import pickle

# %%
with open('random_forest_model.pkl','wb') as file:
    pickle.dump(rf_random,file)

# %%
X.columns
# Out:
# Index(['PresentPrice', 'KmsDriven', 'FuelType', 'SellerType', 'Tranmission',
#        'owner', 'UsageYear'],
#       dtype='object')
